# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %%
path = '/Users/blandt/Desktop/Data/Tomm20/Crosses dark probe/Wild type/200224_kk1273xnwg250/1'

imgG = load_image(glob.glob(path + '/*488 SP 535-50*')[0])
imgR = load_image(glob.glob(path + '/*561 SP 630-75*')[0])
roi = np.loadtxt(path + '/ROI.txt')
imgGr = rotated_embryo(imgG, roi, 350, 270, 3)
imgRr = rotated_embryo(imgR, roi, 350, 270, 3)

# %%
fig, ax = plt.subplots(1, 2)
ax[0].imshow(imgGr, cmap='gray')
ax[1].imshow(imgRr, cmap='gray')
[a.axis('off') for a in ax]
ax[0].set_title('GFP::PAR-2', fontsize=10)
ax[1].set_title('mCherry::PAR-2', fontsize=10)
fig.set_size_inches(4, 2)
fig.tight_layout()
fig.savefig('Figs/dimer_assay.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="400">
