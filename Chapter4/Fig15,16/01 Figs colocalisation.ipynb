# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook
import matplotlib.patches as patches

# %%
def merge(img_c, img_m):
    g = (img_c - np.min(img_c)) / (np.max(img_c) - np.min(img_c))
    r = (img_m - np.min(img_m)) / (np.max(img_m) - np.min(img_m))
    b = np.sqrt((r ** 2) + (g ** 2)) 
#     b = (b - np.min(b)) / (np.max(b) - np.min(b))
    merge = np.dstack((r, g, b))
    return merge

# %% [markdown]
# ### Par2

# %%
ybox = [130, 230]
xbox = [100, 150]
path = '/Users/blandt/Desktop/Data/Tomm20/Crosses tagged probe/191016_nwg231xkk1273/e1'
imgG = load_image(glob.glob(path + '/*488 SP 535-50*')[0])
imgR = load_image(glob.glob(path + '/*561 SP 630-75*')[0])
roi = np.loadtxt(path + '/ROI.txt')
rotatedG = rotated_embryo(imgG, roi, 350, 270, 3)
rotatedR = rotated_embryo(imgR, roi, 350, 270, 3)

# fig, ax = plt.subplots(1, 3)
# ax[0].imshow(rotatedG, cmap='gray')
# ax[1].imshow(rotatedR, cmap='gray')
# [a.axis('off') for a in ax]
# fig.set_size_inches(6, 2)
# fig.tight_layout()

# %%
rect1 = patches.Rectangle((ybox[0], xbox[0]), ybox[1] - ybox[0], xbox[1] - xbox[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none')
rect2 = patches.Rectangle((ybox[0], xbox[0]), ybox[1] - ybox[0], xbox[1] - xbox[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none')
rect3 = patches.Rectangle((ybox[0], xbox[0]), ybox[1] - ybox[0], xbox[1] - xbox[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none')

fig, ax = plt.subplots(1, 3)
ax[0].imshow(rotatedR, cmap='gray')
ax[1].imshow(rotatedG, cmap='gray')
ax[2].imshow(merge(rotatedG, rotatedR))
ax[0].add_patch(rect1)
ax[1].add_patch(rect2)
ax[2].add_patch(rect3)
ax[0].set_title('Tomm20::GBP::mKate', fontsize=10, c='m')
ax[1].set_title('GFP::PAR-2', fontsize=10, c='c')
ax[2].set_title('Merge', fontsize=10)
[a.axis('off') for a in ax]
fig.set_size_inches(6, 2)
fig.tight_layout()
fig.savefig('Figs/coloc_par2.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Par2 zoom

# %%
rotatedG_box = rotatedG[xbox[0]:xbox[1], ybox[0]:ybox[1]]
rotatedR_box = rotatedR[xbox[0]:xbox[1], ybox[0]:ybox[1]]

fig, ax = plt.subplots(1, 3)
ax[0].imshow(rotatedR_box, cmap='gray')
ax[1].imshow(rotatedG_box, cmap='gray')
ax[2].imshow(merge(rotatedG_box, rotatedR_box))
[a.axis('off') for a in ax]
fig.set_size_inches(6, 2)
fig.tight_layout()
fig.savefig('Figs/coloc_par2_zoom.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### PH

# %%
ybox = [20, 120]
xbox = [30, 80]
path = '/Users/blandt/Desktop/Data/Tomm20/Crosses tagged probe/191206_nwg231xlp306/07'
imgG = load_image(glob.glob(path + '/*488 SP 535-50*')[0])
imgR = load_image(glob.glob(path + '/*561 SP 630-75*')[0])
roi = np.loadtxt(path + '/ROI.txt')
rotatedG = rotated_embryo(imgG, roi, 350, 270, 3)
rotatedR = rotated_embryo(imgR, roi, 350, 270, 3)

# %%
rect1 = patches.Rectangle((ybox[0], xbox[0]), ybox[1] - ybox[0], xbox[1] - xbox[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none')
rect2 = patches.Rectangle((ybox[0], xbox[0]), ybox[1] - ybox[0], xbox[1] - xbox[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none')
rect3 = patches.Rectangle((ybox[0], xbox[0]), ybox[1] - ybox[0], xbox[1] - xbox[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none')

fig, ax = plt.subplots(1, 3)
ax[0].imshow(rotatedR, cmap='gray')
ax[1].imshow(rotatedG, cmap='gray')
ax[2].imshow(merge(rotatedG, rotatedR))
ax[0].add_patch(rect1)
ax[1].add_patch(rect2)
ax[2].add_patch(rect3)
ax[0].set_title('Tomm20::GBP::mKate', fontsize=10, c='m')
ax[1].set_title('GFP::PH', fontsize=10, c='c')
ax[2].set_title('Merge', fontsize=10)
[a.axis('off') for a in ax]
fig.set_size_inches(6, 2)
fig.tight_layout()
fig.savefig('Figs/coloc_ph.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### PH zoom

# %%
rotatedG_box = rotatedG[xbox[0]:xbox[1], ybox[0]:ybox[1]]
rotatedR_box = rotatedR[xbox[0]:xbox[1], ybox[0]:ybox[1]]

fig, ax = plt.subplots(1, 3)
ax[0].imshow(rotatedR_box, cmap='gray')
ax[1].imshow(rotatedG_box, cmap='gray')
ax[2].imshow(merge(rotatedG_box, rotatedR_box), cmap='gray')
[a.axis('off') for a in ax]
fig.set_size_inches(6, 2)
fig.tight_layout()
fig.savefig('Figs/coloc_ph_zoom.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
