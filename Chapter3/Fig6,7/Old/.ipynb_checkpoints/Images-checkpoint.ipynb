# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
import seaborn as sns
# %matplotlib notebook

# %%
df = pd.read_csv('df.csv')

# %%
df
# Out:
#      Unnamed: 0  Frame                                               Path  \
# 0             0      0  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 1             1      1  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 2             2      2  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 3             3      3  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 4             4      4  /Users/blandt/Desktop/Analysis/Experiments/e20...
# ..          ...    ...                                                ...
# 102         102    102  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 103         103    103  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 104         104    104  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 105         105    105  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 106         106    106  /Users/blandt/Desktop/Analysis/Experiments/e20...
#
#                                       Folder     Name    Line       Condition  \
# ...

# %%
# images_wt = [load_image(i + '/af_corrected.tif') for i in df[df['Line'] == 'nwg201']['Path']]
# images_c56s = [load_image(i + '/af_corrected.tif') for i in df[df['Line'] == 'nwg246']['Path']]

# %%
# for i in images_wt:
#     fig, ax = plt.subplots()
#     ax.imshow(i)

# %%
paths_wt = df[df['Line'] == 'nwg201'].sort_values('Dosage')['Path'].to_list()
paths_c56s = df[df['Line'] == 'nwg246'].sort_values('Dosage')['Path'].to_list()

dosages_wt = df[df['Line'] == 'nwg201'].sort_values('Dosage')['Dosage'].to_list()
dosages_c56s = df[df['Line'] == 'nwg246'].sort_values('Dosage')['Dosage'].to_list()

# %%
images_wt = [rotated_embryo(load_image(i + '/af_corrected_3channel.tif'), np.loadtxt(i + '/ROI.txt'), 300, 200, 
                            3) for i in paths_wt]

# %%
images_c56s = [rotated_embryo(load_image(i + '/af_corrected_3channel.tif'), np.loadtxt(i + '/ROI.txt'), 300, 200, 
                            3) for i in paths_c56s]

# %%
# for i in images_wt:
#     fig, ax = plt.subplots()
#     ax.imshow(i)

# %%
from scipy.ndimage.filters import gaussian_filter
import ipywidgets as widgets

fig, ax = plt.subplots()
@widgets.interact(i=(0, len(images_wt) - 1, 1))
def update(i=0):
    ax.clear()
    ax.imshow(images_wt[i], cmap='gray')
    ax.axis('off')
    ax.set_title('%s, %s' % (i, dosages_wt[i]))
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='i', max=31), Output()), _dom_classes=('widget-interact',…

# %%
fig, ax = plt.subplots()
@widgets.interact(i=(0, len(images_c56s) - 1, 1))
def update(i=0):
    ax.clear()
    ax.imshow(images_c56s[i], cmap='gray')
    ax.axis('off')
    ax.set_title(i)
# Out:
# <img src="data:image/png;base64,..." width="640">
# interactive(children=(IntSlider(value=0, description='i', max=31), Output()), _dom_classes=('widget-interact',…

# %%
from scipy.ndimage import median_filter

def func(ax, img):
    print(img.shape)
    cyt = np.mean(img[75:125, 125:175])
    ax.imshow(median_filter(img, size=3), cmap='gray', vmin=0, vmax=3 * cyt)
    ax.axis('off')

    
    
fig, axes = plt.subplots(2, 3)

func(axes[0][0], images_wt[8])
func(axes[0][1], images_wt[17])
func(axes[0][2], images_wt[29])

func(axes[1][0], images_c56s[10])
func(axes[1][1], images_c56s[19])
func(axes[1][2], images_c56s[25])

fig.set_size_inches(7, 3)
# Out:
# <img src="data:image/png;base64,..." width="700">
# (200, 300)
# (200, 300)
# (200, 300)
# (200, 300)
# (200, 300)
# (200, 300)
