# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %%
def func(ax, path):
    img = load_image(path + '/af_corrected.tif')
    roi = np.loadtxt(path + '/ROI.txt')
    rotated = rotated_embryo(img, roi, 250, 180, 3)
    ax.imshow(rotated, cmap='gray', vmin=0, vmax=20000)
    ax.axis('off')

# %%
# fig, ax = plt.subplots(2, 3)
# func(ax[0][0], '/Users/blandt/Desktop/Data/PAR2 GCN4/l109r/210428_nwg338_tom4,15,60/00')
# func(ax[1][0], '/Users/blandt/Desktop/Data/Rundowns/PAR-2 RUNDOWN/Experiment/211113_nwg369_wt_tom4,15,60/00')
# func(ax[0][1], '/Users/blandt/Desktop/Data/PAR2 GCN4/wt/210428_lp637_tom4,15,60/13')
# func(ax[1][1], '/Users/blandt/Desktop/Data/Rundowns/PAR-2 RUNDOWN/Experiment/211113_nwg201_wt_tom4,15,60/00')
# func(ax[0][2], '/Users/blandt/Desktop/Data/PAR2 GCN4/wt_gcn4/210722_nwg376_tom4,15,60/00')
# func(ax[1][2], '/Users/blandt/Desktop/Data/PAR2 GCN4/wt_gcn4_par3/211208_nwg437lon_tom4,15,60/00')

# ax[0][0].set_title('PAR-2(L109R)', fontsize=10)
# ax[0][1].set_title('PAR-2(wt)', fontsize=10)
# ax[0][2].set_title('PAR-2(GCN4)', fontsize=10)

# fig.set_size_inches(6, 3)
# fig.tight_layout()

# %%
fig, ax = plt.subplots(1, 3)
func(ax[0], '/Users/blandt/Desktop/Data/PAR2 GCN4/l109r/210428_nwg338_tom4,15,60/00')
func(ax[1], '/Users/blandt/Desktop/Data/PAR2 GCN4/wt/210428_lp637_tom4,15,60/13')
func(ax[2], '/Users/blandt/Desktop/Data/PAR2 GCN4/wt_gcn4/210722_nwg376_tom4,15,60/00')

ax[0].set_title('PAR-2 (L109R)', fontsize=10)
ax[1].set_title('PAR-2 (wt)', fontsize=10)
ax[2].set_title('PAR-2 (GCN4)', fontsize=10)

fig.set_size_inches(6, 1.8)
fig.tight_layout()
fig.savefig('mutant_comparison_for_discussion.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
