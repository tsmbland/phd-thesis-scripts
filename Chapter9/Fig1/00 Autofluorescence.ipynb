# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %%
n2_path = '/Users/blandt/Desktop/Data/T2A/210804_n2_tom4,5,60,500'
n2_paths = direcslist(n2_path)

af = AfCorrelation(n2_paths, sigma=2, expand=10)
af.run()
print(af.params)
af.plot_prediction(s=0.01)
# Out:
# [1.9598844495950971, -624.5325661706606]
# <img src="data:image/png;base64,..." width="640">
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot:xlabel='1.960 * AF + -624.5', ylabel='GFP'>)

# %%
paths = direcslist('/Users/blandt/Desktop/Data/T2A', 1)
for p in paths:
    ch1 = load_image(glob.glob(p + '/*488 SP 535-50*')[0])
    ch2 = load_image(glob.glob(p + '/*488 SP 630-75*')[0])
    corrected = af_subtraction(ch1, ch2, *af.params)
    save_img(corrected, p + '/af_corrected.tif')
