# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
import seaborn as sns
# %matplotlib notebook

# %%
df = pd.read_csv('df.csv')

# %%
fig, ax = plt.subplots()
sns.scatterplot(data=df, x='Cytoplasm', y='Membrane', hue='Line')
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Cytoplasm', ylabel='Membrane'>
