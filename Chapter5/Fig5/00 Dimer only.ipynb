# %%
import sympy as sp
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib notebook

# %% [markdown]
# ### Solving equations

# %% [markdown]
# #### Solving for m

# %%
wd, t, m, c0 = sp.symbols('wd t m c0')

# Conservation of mass
d = t - m

# Chemical potentials
func = sp.exp(wd) -  (d * c0) / (m ** 2)

sp.pprint(sp.solve(func, m))
sp.solve(func, m)
# Out:
# ⎡⎛         ___________________⎞        ⎛        ___________________⎞      ⎤
# ⎢⎜        ╱    ⎛          wd⎞ ⎟  -wd   ⎜       ╱    ⎛          wd⎞ ⎟  -wd ⎥
# ⎢⎝-c₀ + ╲╱  c₀⋅⎝c₀ + 4⋅t⋅ℯ  ⎠ ⎠⋅ℯ     -⎝c₀ + ╲╱  c₀⋅⎝c₀ + 4⋅t⋅ℯ  ⎠ ⎠⋅ℯ    ⎥
# ⎢───────────────────────────────────, ────────────────────────────────────⎥
# ⎣                 2                                    2                  ⎦
# [(-c0 + sqrt(c0*(c0 + 4*t*exp(wd))))*exp(-wd)/2,
#  -(c0 + sqrt(c0*(c0 + 4*t*exp(wd))))*exp(-wd)/2]

# %% [markdown]
# #### Solving for m / c0
#
# No simpler

# %%
sp.simplify(((-c0 + sp.sqrt(c0*(c0 + 4*t*sp.exp(wd))))*sp.exp(-wd)/2) / c0)
# Out:
# (-c0 + sqrt(c0*(c0 + 4*t*exp(wd))))*exp(-wd)/(2*c0)

# %% [markdown]
# ### Figs

# %%
def mon(t, wd, c0=1):
    return (-c0 + np.sqrt(c0*(c0 + 4*t*np.exp(wd))))*np.exp(-wd)/2

def dim(t, wd, c0=1):
    return t - (-c0 + np.sqrt(c0*(c0 + 4*t*np.exp(wd))))*np.exp(-wd)/2

# %% [markdown]
# #### Monomer vs dimer

# %%
fig, ax = plt.subplots()
cs = np.linspace(1e-7, 1e-3, 100)
ax.plot(mon(cs, 10) / 1e-3, dim(cs, 10) / 1e-3)
ax.set_xlabel('Monomer concentration ' + r'$(c_{x_1}) \: _{x 10^{-3}}$')
ax.set_ylabel('Dimer concentration ' + r'$(c_{x_2}) \: _{x 10^{-3}}$')
ax.tick_params(axis='both', labelsize=8)
ax.text(0.1, 0.9, r'$c_{x_2} = e^{w_d/RT}(c_{x_1})^2 / c^{\circ}$', transform=ax.transAxes)

fig.set_size_inches(3, 3)
fig.tight_layout()
fig.savefig('Figs/dimer_only_mon_vs_dim.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# ### Fractions vs total

# %%
fig, ax = plt.subplots()
cs = np.linspace(1e-7, 1e-3, 100)
ax.plot(cs / 1e-3, mon(cs, 10) / cs, label='Monomer ' + r'$(c_{x_1} / c_{tot})$')
ax.plot(cs / 1e-3, dim(cs, 10) / cs, label='Dimer ' + r'$(c_{x_2} / c_{tot})$')

ax.tick_params(axis='both', labelsize=8)
ax.set_xlabel('Total material ' + r'$(c_{tot}) \: _{x 10^{-3}}$')
ax.set_ylabel('Fraction')
ax.set_ylim(0, 1)
ax.legend(frameon=False, fontsize=8)

fig.set_size_inches(3, 3)
fig.tight_layout()
fig.savefig('Figs/dimer_only_fractions_vs_dim.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# ### Reversing the calculation

# %%
wd, t, frac = sp.symbols('wd t frac')

# Chemical potentials
func = sp.exp(wd) -  (frac * t) / (((1 - frac) * t) ** 2)

sp.pprint(sp.solve(func, frac))
sp.solve(func, frac)
# Out:
# ⎡⎛             _____________    ⎞       ⎛             _____________    ⎞     ⎤
# ⎢⎜     wd     ╱      wd         ⎟  -wd  ⎜     wd     ╱      wd         ⎟  -wd⎥
# ⎢⎝2⋅t⋅ℯ   - ╲╱  4⋅t⋅ℯ   + 1  + 1⎠⋅ℯ     ⎝2⋅t⋅ℯ   + ╲╱  4⋅t⋅ℯ   + 1  + 1⎠⋅ℯ   ⎥
# ⎢─────────────────────────────────────, ─────────────────────────────────────⎥
# ⎣                 2⋅t                                    2⋅t                 ⎦
# [(2*t*exp(wd) - sqrt(4*t*exp(wd) + 1) + 1)*exp(-wd)/(2*t),
#  (2*t*exp(wd) + sqrt(4*t*exp(wd) + 1) + 1)*exp(-wd)/(2*t)]

# %%
frac = np.linspace(0.01, 0.99, 1000)
wd = 10
conc = frac*np.exp(-wd)/(frac - 1)**2

fig, ax = plt.subplots()
ax.plot(frac, conc)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
kon, k1, k2, mem, tot, phi = sp.symbols('kon, k1, k2, mem, tot, phi')

# Conservation of mass
cyt = tot - phi * mem

func = (kon * sp.sqrt(2 * k2 * mem + sp.sqrt(4 * k2 * mem + 1) + 1)) / k1 - mem / cyt

# sp.pprint(sp.solve(func, m))
sp.solve(func, mem)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-60022d0d54ab> in <module>
#       7
#       8 # sp.pprint(sp.solve(func, m))
# ----> 9 sp.solve(func, mem)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1092     ###########################################################################
#    1093     if bare_f:
# -> 1094         solution = _solve(f[0], *symbols, **flags)
#    1095     else:
#    1096         solution = _solve_system(f, symbols, **flags)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1669                 else:
#    1670                     try:
# -> 1671                         rv = set(_solve(eq, symbol, **flags))
#    1672                     except NotImplementedError:
#    1673                         rv = None
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1389             # in any factor to zero
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
# -> 1391             result = [s for s in result if
#    1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1391             result = [s for s in result if
#    1392                 all(not checksol(den, {symbol: s}, **flags) for den in
# -> 1393                 dens)]
#    1394         # set flags for quick exit at end; solutions for each
#    1395         # factor were already checked and simplified
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in <genexpr>(.0)
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
#    1391             result = [s for s in result if
# -> 1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#    1394         # set flags for quick exit at end; solutions for each
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     314             # start over without the failed expanded form, possibly
#     315             # with a simplified solution
# --> 316             val = simplify(f.subs(sol))
#     317             if flags.get('force', True):
#     318                 val, reps = posify(val)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     580             x, handled),
#     581         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
# --> 582         simultaneous=False)
#     583     if not isinstance(expr, handled):
#     584         return done(expr)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in replace(self, query, value, map, simultaneous, exact)
#    1513             return expr
#    1514
# -> 1515         rv = bottom_up(self, rec_replace, atoms=True)
#    1516
#    1517         # restore original expressions for Dummy symbols
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in rec_replace(expr)
#    1494             result = _query(expr)
#    1495             if result or result == {}:
# -> 1496                 new = _value(expr, result)
#    1497                 if new is not None and new != expr:
#    1498                     mapping[expr] = new
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in <lambda>(expr, result)
#    1478
#    1479             if callable(value):
# -> 1480                 _value = lambda expr, result: value(expr)
#    1481             else:
#    1482                 raise TypeError(
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <lambda>(x)
#     579         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     580             x, handled),
# --> 581         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     582         simultaneous=False)
#     583     if not isinstance(expr, handled):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#     579         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     580             x, handled),
# --> 581         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     582         simultaneous=False)
#     583     if not isinstance(expr, handled):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     557     _eval_simplify = getattr(expr, '_eval_simplify', None)
#     558     if _eval_simplify is not None:
# --> 559         return _eval_simplify(**kwargs)
#     560
#     561     original_expr = expr = collect_abs(signsimp(expr))
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in _eval_simplify(self, **kwargs)
#      56
#      57     def _eval_simplify(self, **kwargs):
# ---> 58         return self.func(*[a.simplify(**kwargs) for a in self.args])
#      59
#      60 class Piecewise(Function):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in <listcomp>(.0)
#      56
#      57     def _eval_simplify(self, **kwargs):
# ---> 58         return self.func(*[a.simplify(**kwargs) for a in self.args])
#      59
#      60 class Piecewise(Function):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in simplify(self, **kwargs)
#    1673         """See the simplify function in sympy.simplify"""
#    1674         from sympy.simplify import simplify
# -> 1675         return simplify(self, **kwargs)
#    1676
#    1677     def _eval_rewrite(self, pattern, rule, **hints):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     600     expr = bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     601     expr = Mul(*powsimp(expr).as_content_primitive())
# --> 602     _e = cancel(expr)
#     603     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     604     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6664
#    6665     try:
# -> 6666         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6667     except PolificationFailed:
#    6668         if not isinstance(f, (tuple, Tuple)):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/polys/polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4310     """Construct polynomials from expressions. """
#    4311     opt = options.build_options(gens, args)
# -> 4312     return _parallel_poly_from_expr(exprs, opt)
#    4313
#    4314
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/polys/polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4349
#    4350                 if opt.expand:
# -> 4351                     expr = expr.expand()
#    4352         else:
#    4353             failed = True
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3481             if use_hint:
#    3482                 hint = '_eval_expand_' + hint
# -> 3483                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3484
#    3485         while True:
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
# -> 3418                 sargs.append(arg)
#    3419
#    3420             if hit:
#
# KeyboardInterrupt:

# %%
kon, k1, k2, mem, tot, phi = sp.symbols('kon, k1, k2, mem, tot, phi')

# Conservation of mass
cyt = tot - phi * mem

func = ((kon * sp.sqrt(2 * k2 * mem + sp.sqrt(4 * k2 * mem + 1) + 1)) / k1) - (mem / cyt)

sp.solve(func, mem)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-20f324a3b342> in <module>
#       6 func = ((kon * sp.sqrt(2 * k2 * mem + sp.sqrt(4 * k2 * mem + 1) + 1)) / k1) - (mem / cyt)
#       7
# ----> 8 sp.solve(func, mem)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in solve(f, *symbols, **flags)
#    1092     ###########################################################################
#    1093     if bare_f:
# -> 1094         solution = _solve(f[0], *symbols, **flags)
#    1095     else:
#    1096         solution = _solve_system(f, symbols, **flags)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1669                 else:
#    1670                     try:
# -> 1671                         rv = set(_solve(eq, symbol, **flags))
#    1672                     except NotImplementedError:
#    1673                         rv = None
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in _solve(f, *symbols, **flags)
#    1389             # in any factor to zero
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
# -> 1391             result = [s for s in result if
#    1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in <listcomp>(.0)
#    1391             result = [s for s in result if
#    1392                 all(not checksol(den, {symbol: s}, **flags) for den in
# -> 1393                 dens)]
#    1394         # set flags for quick exit at end; solutions for each
#    1395         # factor were already checked and simplified
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in <genexpr>(.0)
#    1390             dens = flags.get('_denominators', _simple_dens(f, symbols))
#    1391             result = [s for s in result if
# -> 1392                 all(not checksol(den, {symbol: s}, **flags) for den in
#    1393                 dens)]
#    1394         # set flags for quick exit at end; solutions for each
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in checksol(f, symbol, sol, **flags)
#     314             # start over without the failed expanded form, possibly
#     315             # with a simplified solution
# --> 316             val = simplify(f.subs(sol))
#     317             if flags.get('force', True):
#     318                 val, reps = posify(val)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     580             x, handled),
#     581         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
# --> 582         simultaneous=False)
#     583     if not isinstance(expr, handled):
#     584         return done(expr)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in replace(self, query, value, map, simultaneous, exact)
#    1513             return expr
#    1514
# -> 1515         rv = bottom_up(self, rec_replace, atoms=True)
#    1516
#    1517         # restore original expressions for Dummy symbols
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#    1147     if args is not None:
#    1148         if args:
# -> 1149             args = tuple([bottom_up(a, F, atoms, nonbasic) for a in args])
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in bottom_up(rv, F, atoms, nonbasic)
#    1150             if args != rv.args:
#    1151                 rv = rv.func(*args)
# -> 1152             rv = F(rv)
#    1153         elif atoms:
#    1154             rv = F(rv)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in rec_replace(expr)
#    1494             result = _query(expr)
#    1495             if result or result == {}:
# -> 1496                 new = _value(expr, result)
#    1497                 if new is not None and new != expr:
#    1498                     mapping[expr] = new
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in <lambda>(expr, result)
#    1478
#    1479             if callable(value):
# -> 1480                 _value = lambda expr, result: value(expr)
#    1481             else:
#    1482                 raise TypeError(
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <lambda>(x)
#     579         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     580             x, handled),
# --> 581         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     582         simultaneous=False)
#     583     if not isinstance(expr, handled):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in <listcomp>(.0)
#     579         lambda x: isinstance(x, Expr) and x.args and not isinstance(
#     580             x, handled),
# --> 581         lambda x: x.func(*[simplify(i, **kwargs) for i in x.args]),
#     582         simultaneous=False)
#     583     if not isinstance(expr, handled):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     557     _eval_simplify = getattr(expr, '_eval_simplify', None)
#     558     if _eval_simplify is not None:
# --> 559         return _eval_simplify(**kwargs)
#     560
#     561     original_expr = expr = collect_abs(signsimp(expr))
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in _eval_simplify(self, **kwargs)
#      56
#      57     def _eval_simplify(self, **kwargs):
# ---> 58         return self.func(*[a.simplify(**kwargs) for a in self.args])
#      59
#      60 class Piecewise(Function):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/functions/elementary/piecewise.py in <listcomp>(.0)
#      56
#      57     def _eval_simplify(self, **kwargs):
# ---> 58         return self.func(*[a.simplify(**kwargs) for a in self.args])
#      59
#      60 class Piecewise(Function):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in simplify(self, **kwargs)
#    1673         """See the simplify function in sympy.simplify"""
#    1674         from sympy.simplify import simplify
# -> 1675         return simplify(self, **kwargs)
#    1676
#    1677     def _eval_rewrite(self, pattern, rule, **hints):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/simplify/simplify.py in simplify(expr, ratio, measure, rational, inverse, doit, **kwargs)
#     600     expr = bottom_up(expr, lambda w: getattr(w, 'normal', lambda: w)())
#     601     expr = Mul(*powsimp(expr).as_content_primitive())
# --> 602     _e = cancel(expr)
#     603     expr1 = shorter(_e, _mexpand(_e).cancel())  # issue 6829
#     604     expr2 = shorter(together(expr, deep=True), together(expr1, deep=True))
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/polys/polytools.py in cancel(f, *gens, **args)
#    6664
#    6665     try:
# -> 6666         (F, G), opt = parallel_poly_from_expr((p, q), *gens, **args)
#    6667     except PolificationFailed:
#    6668         if not isinstance(f, (tuple, Tuple)):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/polys/polytools.py in parallel_poly_from_expr(exprs, *gens, **args)
#    4310     """Construct polynomials from expressions. """
#    4311     opt = options.build_options(gens, args)
# -> 4312     return _parallel_poly_from_expr(exprs, opt)
#    4313
#    4314
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/polys/polytools.py in _parallel_poly_from_expr(exprs, opt)
#    4349
#    4350                 if opt.expand:
# -> 4351                     expr = expr.expand()
#    4352         else:
#    4353             failed = True
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in expand(self, deep, modulus, power_base, power_exp, mul, log, multinomial, basic, **hints)
#    3481             if use_hint:
#    3482                 hint = '_eval_expand_' + hint
# -> 3483                 expr, hit = Expr._expand_hint(expr, hint, deep=deep, **hints)
#    3484
#    3485         while True:
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3414             sargs = []
#    3415             for arg in expr.args:
# -> 3416                 arg, arghit = Expr._expand_hint(arg, hint, **hints)
#    3417                 hit |= arghit
#    3418                 sargs.append(arg)
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in _expand_hint(expr, hint, deep, **hints)
#    3423         if hasattr(expr, hint):
#    3424             newexpr = getattr(expr, hint)(**hints)
# -> 3425             if newexpr != expr:
#    3426                 return (newexpr, True)
#    3427
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/basic.py in __ne__(self, other)
#     364         but faster
#     365         """
# --> 366         return not self == other
#     367
#     368     def dummy_eq(self, other, symbol=None):
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/core/expr.py in __eq__(self, other)
#     140             if not isinstance(a, Expr):
#     141                 continue
# --> 142             if a.is_Number and type(a) != type(b):
#     143                 return False
#     144         return True
#
# KeyboardInterrupt:

# %%
def func(kon, k1, k2, tot, phi):
    mem = sp.Symbol('mem')
    cyt = tot - phi * mem
    func1 = (kon * sp.sqrt(2 * k2 * mem + sp.sqrt(4 * k2 * mem + 1) + 1)) / k1 
    func2 = mem / cyt
    sp.nsolve([func1, func2], [mem, ], [0,])

# %%
func(kon=0.1, k1=0.01, k2=100, tot=1, phi=0.1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-baa61372d1cb> in <module>
# ----> 1 func(kon=0.1, k1=0.01, k2=100, tot=1, phi=0.1)
#
# <ipython-input-31-464798a17e74> in func(kon, k1, k2, tot, phi)
#       4     func1 = (kon * sp.sqrt(2 * k2 * mem + sp.sqrt(4 * k2 * mem + 1) + 1)) / k1
#       5     func2 = mem / cyt
# ----> 6     sp.nsolve([func1, func2], [mem, ], [0,])
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/utilities/decorator.py in func_wrapper(*args, **kwargs)
#      88         dps = mpmath.mp.dps
#      89         try:
# ---> 90             return func(*args, **kwargs)
#      91         finally:
#      92             mpmath.mp.dps = dps
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/sympy/solvers/solvers.py in nsolve(*args, **kwargs)
#    3033     J = lambdify(fargs, J, modules)
#    3034     # solve the system numerically
# -> 3035     x = findroot(f, x0, J=J, **kwargs)
#    3036     if as_dict:
#    3037         return [dict(zip(fargs, [sympify(xi) for xi in x]))]
#
# ~/anaconda3/anaconda3/envs/model/lib/python3.7/site-packages/mpmath/calculus/optimization.py in findroot(ctx, f, x0, solver, tol, verbose, verify, **kwargs)
#     977                              '(%s > %s)\n'
#     978                              'Try another starting point or tweak arguments.'
# --> 979                              % (norm(f(*xl))**2, tol))
#     980         return x
#     981     finally:
#
# ValueError: Could not find root within given tolerance. (64.2436967242484768928 > 2.16840434497100886801e-19)
# Try another starting point or tweak arguments.

# %%
phi, m, alpha, tot = sp.symbols('phi m alpha tot')

func = m / (tot - phi * m) - alpha

sp.solve(func, m)
# Out:
# [alpha*tot/(alpha*phi + 1)]
