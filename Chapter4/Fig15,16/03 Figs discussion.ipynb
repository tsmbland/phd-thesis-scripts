# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %%
path_par2 = '/Users/blandt/Desktop/Data/Tomm20/Crosses tagged probe/191016_nwg231xkk1273/e1'
path_par2_pkc = '/Users/blandt/Desktop/Data/Tomm20/Crosses dark probe/PKC RNAi/200228_kk1273xnwg250_2002271030pkc3/01/'
path_par1 = '/Users/blandt/Desktop/Data/Tomm20/Crosses dark probe/PAR1 assay/200304_kk1262xnwg250/00'

roi_par2 = np.loadtxt(path_par2 + '/ROI.txt')
roi_par2_pkc = np.loadtxt(path_par2_pkc + '/ROI.txt')
roi_par1 = np.loadtxt(path_par1 + '/ROI.txt')

img_par2 = load_image(glob.glob(path_par2 + '/*488 SP 535-50*')[0])
img_par2_pkc = load_image(glob.glob(path_par2_pkc + '/*488 SP 535-50*')[0])
img_par1 = load_image(glob.glob(path_par1 + '/*488 SP 535-50*')[0])

rotated_par2 = rotated_embryo(img_par2, roi_par2, 350, 270, 3)
rotated_par2_pkc = rotated_embryo(img_par2_pkc, roi_par2_pkc, 350, 270, 3)
rotated_par1 = rotated_embryo(img_par1, roi_par1, 350, 270, 3)

# %%
fig, ax = plt.subplots(1, 3)
ax[0].imshow(rotated_par2, cmap='gray', vmin=0)
ax[1].imshow(rotated_par2_pkc, cmap='gray', vmin=0)
ax[2].imshow(rotated_par1, cmap='gray', vmin=0)
ax[0].set_title('GFP::PAR-2', fontsize=10)
ax[1].set_title('GFP::PAR-2, pkc-3(RNAi)', fontsize=10)
ax[2].set_title('PAR-1::GFP', fontsize=10)
[a.axis('off') for a in ax]
fig.set_size_inches(6, 2)
fig.tight_layout()
fig.savefig('Figs/par2_vs_par1.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="600">
