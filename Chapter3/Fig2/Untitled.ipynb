# %%
import sys
sys.path.append('../../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %% [markdown]
# ### Normal polarity

# %%
x = np.arange(0, 100)
A = (error_func(x, 52, 10)[::-1] + 1) / 2
P = (error_func(x, 52, 10) + 1) / 2

fig, ax = plt.subplots()
ax.plot(x, A, c='tab:red')
ax.plot(x, P, c='dodgerblue')
ax.set_xticks([])
ax.set_yticks([])
# ax.set_ylim([0, 1.1])
ax.set_ylabel('Concentration')
ax.set_xlabel('Position')
fig.set_size_inches(2, 1.7)
fig.tight_layout()
fig.savefig('normal_polarity.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# ### S241A

# %%
x = np.arange(0, 100)
A = (error_func(x, 52, 10)[::-1] + 1) / 2
P = np.ones(100) * 0.6

fig, ax = plt.subplots()
ax.plot(x, A, c='tab:red')
ax.plot(x, P, c='dodgerblue')
ax.set_xticks([])
ax.set_yticks([])
# ax.set_ylim([0, 1.1])
ax.set_ylabel('Concentration')
ax.set_xlabel('Position')
fig.set_size_inches(2, 1.7)
fig.tight_layout()
fig.savefig('s241a.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="200">

# %% [markdown]
# ### No flow S950A

# %%
x = np.arange(0, 100)
A = np.ones(100) * 0.6
P = (error_func(x, 52, 10) + 1) / 2

fig, ax = plt.subplots()
ax.plot(x, A, c='tab:red')
ax.plot(x, P, c='dodgerblue')
ax.set_xticks([])
ax.set_yticks([])
# ax.set_ylim([0, 1.1])
ax.set_ylabel('Concentration')
ax.set_xlabel('Position')
fig.set_size_inches(2, 1.7)
fig.tight_layout()
fig.savefig('no_flow_s950a.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="200">
