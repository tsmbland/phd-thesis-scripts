# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
import seaborn as sns
# %matplotlib notebook

# %%
def func(path):
    img = load_image(path + '/af_corrected.tif')
    roi = np.loadtxt(path + '/ROI.txt')
    img_rotated = rotated_embryo(img, roi, l=250, h=200, order=3)
    return img_rotated

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(1, 6)

ax1.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_lp637_tom4,15,60/02'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax2.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_nwg376_tom4,15,60/00'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax3.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2104__par2_mutants/210428_nwg240_tom4,16,50/05'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax4.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210816_nwg381_tom4,15,60/02'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax5.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2104__par2_mutants/210428_nwg338_tom4,15,60/00'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax6.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210903_nwg398_tom4,15,60/line11_00'), 
           vmin=0-1000, vmax=30000, cmap='gray')

# ax1.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_lp637_tom4,15,60/02'), 
#            vmin=0, vmax=None, cmap='gray')
# ax2.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_nwg376_tom4,15,60/00'), 
#            vmin=0, vmax=None, cmap='gray')
# ax3.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2104__par2_mutants/210428_nwg240_tom4,16,50/05'), 
#            vmin=0, vmax=None, cmap='gray')
# ax4.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210816_nwg381_tom4,15,60/02'), 
#            vmin=0, vmax=None, cmap='gray')
# ax5.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2104__par2_mutants/210428_nwg338_tom4,15,60/00'), 
#            vmin=0, vmax=None, cmap='gray')
# ax6.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210903_nwg398_tom4,15,60/line11_00'), 
#            vmin=0, vmax=None, cmap='gray')

ax1.axis('off')
ax2.axis('off')
ax3.axis('off')
ax4.axis('off')
ax5.axis('off')
ax6.axis('off')

ax1.set_title('Wild type')
ax2.set_title('GCN4')
ax3.set_title('C56S')
ax4.set_title('C56S_GCN4')
ax5.set_title('L109R')
ax6.set_title('L109R_GCN4')

fig.set_size_inches(8, 2)
fig.tight_layout()
# fig.savefig('Figs/embryos.png')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4)

ax1.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_lp637_tom4,15,60/02'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax2.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_nwg376_tom4,15,60/00'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax3.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2104__par2_mutants/210428_nwg338_tom4,15,60/00'), 
           vmin=-1000, vmax=30000, cmap='gray')
ax4.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210903_nwg398_tom4,15,60/line11_00'), 
           vmin=0-1000, vmax=30000, cmap='gray')

# ax1.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_lp637_tom4,15,60/02'), 
#            vmin=0, vmax=None, cmap='gray')
# ax2.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210722_nwg376_tom4,15,60/00'), 
#            vmin=0, vmax=None, cmap='gray')
# ax3.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2104__par2_mutants/210428_nwg338_tom4,15,60/00'), 
#            vmin=0, vmax=None, cmap='gray')
# ax4.imshow(func('/Users/blandt/Desktop/Analysis/Experiments/e2107__gcn4/210903_nwg398_tom4,15,60/line11_00'), 
#            vmin=0, vmax=None, cmap='gray')

ax1.axis('off')
ax2.axis('off')
ax3.axis('off')
ax4.axis('off')

ax1.set_title('Wild type')
ax2.set_title('GCN4')
ax3.set_title('L109R')
ax4.set_title('L109R_GCN4')

fig.set_size_inches(8, 2)
fig.tight_layout()
# fig.savefig('Figs/embryos.png')
# Out:
# <img src="data:image/png;base64,..." width="800">
