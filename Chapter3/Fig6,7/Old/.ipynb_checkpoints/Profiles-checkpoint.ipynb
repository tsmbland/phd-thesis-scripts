# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %%
path = '/Users/blandt/Desktop/Analysis/Experiments/e2001__par2_rundown/'
direcs = direcslist(path, 1)

straights = []
for d in direcs:
    img = load_image(d + '/af_corrected.tif')
    roi = np.loadtxt(d + '/ROI_fitted.txt')
    straights.append(straighten(img, roi, 50))

# %%
profs = np.zeros([len(direcs), 50])
profs_norm = np.zeros([len(direcs), 50])
for i, s in enumerate(straights):
    profs[i] = bounded_mean_2d(s, [0, 1])
    profs_norm[i] = profs[i] / np.mean(profs[i][45:])

# %%
df = pd.read_csv('df.csv')
print(df)
# Out:
#      Unnamed: 0  Frame                                               Path  \
# 0             0      0  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 1             1      1  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 2             2      2  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 3             3      3  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 4             4      4  /Users/blandt/Desktop/Analysis/Experiments/e20...
# ..          ...    ...                                                ...
# 102         102    102  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 103         103    103  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 104         104    104  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 105         105    105  /Users/blandt/Desktop/Analysis/Experiments/e20...
# 106         106    106  /Users/blandt/Desktop/Analysis/Experiments/e20...
#
#                                       Folder     Name    Line       Condition  \
# ...

# %%
ax = plt.axes(projection='3d')
condition = (df['Dosage'] > 500) * (df['Line'] == 'nwg246')
profs_norm_thresh = profs_norm[condition]
dosages_thresh = df['Dosage'][condition]
for d, p in zip(dosages_thresh, profs_norm_thresh):
    ax.plot(np.arange(50), np.ones(50) * d/ 1000, p, alpha=0.8)
    
ax.set_ylabel('\n\nTotal PAR-2 (a.u.)')
ax.set_zlabel('\nNormalised intensity')
ax.set_xlabel('\nPosition (pixels)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /anaconda/envs/membranequant/lib/python3.7/site-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
# Text(0.5, 0, '\nPosition (pixels)')

# %%
ax = plt.axes(projection='3d')
condition = (df['Dosage'] > 500) * (df['Line'] == 'lp637')
profs_norm_thresh = profs_norm[condition]
dosages_thresh = df['Dosage'][condition]
for d, p in zip(dosages_thresh, profs_norm_thresh):
    ax.plot(np.arange(50), np.ones(50) * d, p, c='k', alpha=0.5)
# Out:
# /anaconda/envs/membranequant/lib/python3.7/site-packages/pandas/core/computation/expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "
