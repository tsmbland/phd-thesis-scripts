# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
import seaborn as sns
# %matplotlib notebook

# %% [markdown]
# ### Images: wt vs gcn4, raw vs corrected

# %%
path_wt = direcslist('/Users/blandt/Desktop/Data/PAR2 GCN4/wt', 1)[0]
path_gcn4 = direcslist('/Users/blandt/Desktop/Data/PAR2 GCN4/wt_gcn4', 1)[0]

# def func_af(path, ax):
#     img = load_image(path + '/af_corrected.tif')
#     roi = np.loadtxt(path + '/ROI.txt')
#     rotated = rotated_embryo(img, roi, 250, 200, 3)
#     ax.imshow(rotated, cmap='gray', vmin=0, vmax=20000)
#     ax.axis('off')
    
# def func_raw(path, ax):
#     img = load_image(glob.glob(path + '/*488 SP 535-50*')[0])
#     roi = np.loadtxt(path + '/ROI.txt')
#     rotated = rotated_embryo(img, roi, 250, 200, 3)
#     ax.imshow(rotated, cmap='gray', vmin=0, vmax=30000)
#     ax.axis('off')
    
# fig, ax = plt.subplots(2, 2)
# func_raw(path_wt, ax[0][0])
# func_raw(path_gcn4, ax[0][1])
# func_af(path_wt, ax[1][0])
# func_af(path_gcn4, ax[1][1])
# ax[0][0].set_title('mNG::PAR-2', fontsize=9)
# ax[0][1].set_title('mNG::PAR-2(GCN4)', fontsize=9)
# fig.set_size_inches(4, 3)
# fig.tight_layout()

# %% [markdown]
# ### Zoomed images: endosomes

# %%
ybox_a = [70, 130]
xbox_a = [80, 160]

def func(path, ax):
    img = load_image(path + '/af_corrected.tif')
    roi = np.loadtxt(path + '/ROI.txt')
    rotated = rotated_embryo(img, roi, 250, 180, 3)
    rotated_box = rotated[xbox_a[0]:xbox_a[1], ybox_a[0]:ybox_a[1]]
    ax.imshow(rotated_box, cmap='viridis', vmin=0, vmax=13000)
    ax.axis('off')
    
fig, ax = plt.subplots(1, 2)
func(path_wt, ax[0])
func(path_gcn4, ax[1])
fig.set_size_inches(3, 2)
fig.savefig('Figs/imgs_endosomes_zoom.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# ### Zoomed images: anterior membrane

# %%
ybox_b = [10, 60]
xbox_b = [50, 150]

def func(path, ax):
    img = load_image(path + '/af_corrected.tif')
    roi = np.loadtxt(path + '/ROI.txt')
    rotated = rotated_embryo(img, roi, 250, 180, 3)
    rotated_box = rotated[xbox_b[0]:xbox_b[1], ybox_b[0]:ybox_b[1]]
    ax.imshow(rotated_box, cmap='viridis', vmin=0, vmax=8000)
    ax.axis('off')
    
fig, ax = plt.subplots(1, 2)
func(path_wt, ax[0])
func(path_gcn4, ax[1])
fig.set_size_inches(3, 3)
fig.savefig('Figs/imgs_anterior_zoom.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# ### Images with boxes

# %%
import matplotlib.patches as patches

def func_af(path, ax):
    img = load_image(path + '/af_corrected.tif')
    roi = np.loadtxt(path + '/ROI.txt')
    rotated = rotated_embryo(img, roi, 250, 200, 3)
    ax.imshow(rotated, cmap='gray', vmin=0, vmax=20000)
    ax.set_xticks([])
    ax.set_yticks([])
    
    # Endosome box
    recta = patches.Rectangle((ybox_a[0], xbox_a[0]), ybox_a[1] - ybox_a[0], xbox_a[1] - xbox_a[0], 
                         linewidth=1, edgecolor='tab:blue', facecolor='none', linestyle='--')
    ax.add_patch(recta)
    
    # Anterior membrane box
    rectb = patches.Rectangle((ybox_b[0], xbox_b[0]), ybox_b[1] - ybox_b[0], xbox_b[1] - xbox_b[0], 
                         linewidth=1, edgecolor='tab:orange', facecolor='none', linestyle='--')
    ax.add_patch(rectb)

    
def func_raw(path, ax):
    img = load_image(glob.glob(path + '/*488 SP 535-50*')[0])
    roi = np.loadtxt(path + '/ROI.txt')
    rotated = rotated_embryo(img, roi, 250, 200, 3)
    ax.imshow(rotated, cmap='gray', vmin=0, vmax=30000)
    ax.set_xticks([])
    ax.set_yticks([])
    
fig, ax = plt.subplots(2, 2)
func_raw(path_wt, ax[0][0])
func_raw(path_gcn4, ax[0][1])
func_af(path_wt, ax[1][0])
func_af(path_gcn4, ax[1][1])
ax[0][0].set_title('mNG::PAR-2', fontsize=10)
ax[0][1].set_title('mNG::PAR-2(GCN4)', fontsize=10)
ax[0][0].set_ylabel('Raw', fontsize=10)
ax[1][0].set_ylabel('SAIBR', fontsize=10)
fig.set_size_inches(4.5, 4)
fig.tight_layout()
fig.savefig('Figs/imgs.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="450">

# %% [markdown]
# ### Timelapse: GCN4 (corrected)

# %%
# movie = load_image('/Users/blandt/Desktop/Data/PAR2 GCN4/wt_gcn4_movies!/_03_corrected.tif')
# print(movie.shape)
# timepoints = [0, 3, 9, 13]
# # timepoints = [24, 25, 26, 27]


# def func(timepoint, ax):
#     img = movie[timepoint]
#     ax.imshow(img, cmap='gray', vmin=0, vmax=15000)
#     ax.set_xticks([])
#     ax.set_yticks([])

# fig, ax = plt.subplots(1, 4)
# func(timepoints[0], ax[0])
# func(timepoints[1], ax[1])
# func(timepoints[2], ax[2])
# func(timepoints[3], ax[3])
# fig.set_size_inches(8, 2)
# fig.tight_layout()

# %%
movie = load_image('/Users/blandt/Desktop/Data/PAR2 GCN4/wt_gcn4_movies!/_03_corrected.tif')
print(movie.shape)
timepoints = [0, 3, 9, 17, 23]
labels = ['0 min', '3 min', '9 min', '17 min', '27 min']
# timepoints = [24, 25, 26, 27]


def func(timepoint, ax):
    img = movie[timepoint]
    ax.imshow(img, cmap='gray', vmin=0, vmax=15000)
    ax.axis('off')

fig, ax = plt.subplots(1, 5)
func(timepoints[0], ax[0])
func(timepoints[1], ax[1])
func(timepoints[2], ax[2])
func(timepoints[3], ax[3])
func(timepoints[4], ax[4])
[a.set_title(l, fontsize=12) for a, l in zip(ax, labels)]
fig.set_size_inches(8, 1.5)
fig.tight_layout()
fig.subplots_adjust(wspace=0)
fig.savefig('Figs/imgs_gcn4_timelapse.png', dpi=600, transparent=True)
# Out:
# (38, 198, 260)
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### Membrane quantification: wt vs GCN4

# %%
res = pd.read_csv('res.csv')
df = pd.read_csv('df.csv')

def fold(array):
    return (array[:50][::-1] + array[50:]) / 2

mems = res.groupby('Frame').apply(lambda x: x['Membrane signal'].to_numpy())
mems = np.array([fold(x) / 10000 for x in mems])

def func(condition, ax, c, label):
    mems_ = mems[df.Condition == condition]
    mems_mean = np.mean(mems_, axis=0)
    mems_std = np.std(mems_, axis=0)
    ax.plot(mems_mean, c=c, label=label)
    ax.fill_between(np.arange(50), mems_mean - mems_std, mems_mean + mems_std, color=c, alpha=0.2)

   
fig, ax = plt.subplots()
func('wt', ax, 'tab:blue', 'PAR-2')
func('wt_gcn4', ax, 'tab:orange', 'PAR-2(GCN4)')
ax.set_ylim(bottom=0)
ax.set_xlabel('Anterior      Midcell      Posterior')
ax.set_ylabel('Membrane concentration (a.u.)')
ax.set_xticks([])
# ax.set_ylim(0, 3.5)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
ax.legend(fontsize=8)
fig.set_size_inches(3,2.5)
fig.tight_layout()
fig.savefig('Figs/conc_profile_wt_vs_gcn4.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="300">

# %% [markdown]
# ### Dosage: wt vs GCN4

# %%
fig, ax = plt.subplots()
order = ['wt', 'wt_gcn4']
sns.stripplot(data=df, x='Condition', y='Dosage', ax=ax, order=order)
sns.barplot(data=df, x='Condition', y ='Dosage', order=order, alpha=0.3, errwidth=0)
for tick in ax.get_xticklabels():
    tick.set_rotation(45)
    tick.set_horizontalalignment('right')
ax.set_xlabel('')
ax.set_ylabel('Dosage (a.u.)')
ax.set_xticklabels(['PAR-2', 'PAR-2(GCN4)'])
ax.tick_params(axis='both', labelsize=8)
fig.set_size_inches(2, 2.5)
fig.tight_layout()
fig.savefig('Figs/dosage_wt_vs_gcn4.png', dpi=600, transparent=True)
# Out:
# <img src="data:image/png;base64,..." width="200">
