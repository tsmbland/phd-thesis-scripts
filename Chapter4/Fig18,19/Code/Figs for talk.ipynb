# %%
import sys
sys.path.append('../../MembraneQuant')
from membranequant import *
# %matplotlib notebook

# %% [markdown]
# ## Images

# %%
def func(path, name, vmin=-200, vmax=2000):
    img = load_image(path + '/af_corrected.tif')
    roi = np.loadtxt(path + '/ROI.txt')
    img_rotated = rotated_embryo(img, roi, 250, 200, 3)
    
    fig, ax = plt.subplots()
    ax.imshow(img_rotated, cmap='gray', vmin=vmin, vmax=vmax)
    ax.axis('off')
    fig.set_size_inches(3,3)
    
    save_img_jpeg(img_rotated, name + '.jpeg', cmin=vmin, cmax=vmax, cmap='gray')

# %%
func('/Users/blandt/Desktop/Analysis/Experiments/e2011__ring_ph/wt/201014_ptb5_tom4,15,60_eb,15beads/03',
    name='ph_ring_example')
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
func('/Users/blandt/Desktop/Analysis/Experiments/e1902__ph_rundown/od58_rd/190222_od58_1902211900xfp_tom4,5,30(500msec)/06',
    name='ph_example')
# Out:
# <img src="data:image/png;base64,..." width="300">

# %%
func('/Users/blandt/Desktop/Analysis/Experiments/e2107__ptb6_testing/210701_nwg373_tom4,15,60/00',
    name='ph_ring_c56s_example')
# Out:
# <img src="data:image/png;base64,..." width="300">
